# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("kc_house_data.csv")
df.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %% [markdown]
# Условие 1: Задача 1
# Постройте график
# Назовите график
# Сделайте именование оси x и оси y
# Сделайте выводы
#
# 1.1. Скачать следующие данные: kc-house-data и laptop_price
# 1.2. Изучите стоимости недвижимости

# %%
plt.figure(figsize=(6,4))
plt.hist(df['price'])
plt.title('график')
plt.xlabel('количество')
plt.ylabel('долларов')




# sns.hisplot(x=sqft_living);
# Out:
# Text(0, 0.5, 'долларов')

# %% [markdown]
# 1.3. Изучите распределение квадратуры жилой
# 1.4. Изучите распределение года постройки

# %%
data=df['sqft_living'].value_counts()
plt.bar(data.index, data.values)
plt.title('График распределения жилой площади')
# Out:
# Text(0.5, 1.0, 'График распределения жилой площади')

# %%
data1=df['yr_built'].value_counts()
plt.bar(data1.index, data1.values)
plt.title('График распределения годов постройки')
# Out:
# Text(0.5, 1.0, 'График распределения годов постройки')

# %% [markdown]
# Условие 2: 2 задача
# 2.1. Изучите распределение домов от наличия вида на набережную
# Постройте график
# Сделайте выводы
# 2.2. Изучите распределение этажей домов
# 2.3. Изучите распределение состояния домов

# %%
data5=df['view'].value_counts()
plt.bar(data5.index, data5.values)
plt.title('График распределения домов от наличия вида на набережную')
# Out:
# Text(0.5, 1.0, 'График распределения домов от наличия вида на набережную')

# %%
data2=df['floors'].value_counts()
plt.bar(data2.index, data2.values)
plt.title('График распределения этажей')
# Out:
# Text(0.5, 1.0, 'График распределения этажей')

# %%
data4=df['grade'].value_counts()
plt.bar(data4.index, data4.values)
plt.title('График распределения состояния домов')
# Out:
# Text(0.5, 1.0, 'График распределения состояния домов')

# %% [markdown]
# Условие 3: 3 задача
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
# Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями
